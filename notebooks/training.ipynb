# %% [markdown]
# Read dataframe

# %%
import weakref
import pandas as pd
dataset = '/home/gianlu/Documents/Dev/irony-detection/data/processed/TwReyes2013/labeled_matrix-bow.csv'
df = pd.read_csv(dataset)
d = 
X = df.values
del df
print(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-eac21fbecc5c> in <module>
#       3 dataset = '/home/gianlu/Documents/Dev/irony-detection/data/processed/TwReyes2013/labeled_matrix-bow.csv'
#       4 df = weakref.ref(pd.read_csv(dataset))
# ----> 5 X = df.values
#       6 del df
#       7 print(X)
#
# AttributeError: 'weakref' object has no attribute 'values'

# %%
#X = df.values
df
# Out:
# <weakref at 0x7fe2f17eb8f0; dead>

# %%
import numpy as np
import gc


X = df.drop(['label'], axis=1).values
y = df['label']
del df
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ff6445aaac8b> in <module>
#       3
#       4
# ----> 5 X = df.drop(['label'], axis=1).values
#       6 y = df['label']
#       7 del df
#
# AttributeError: 'weakref' object has no attribute 'drop'

# %%
from sklearn.model_selection import train_test_split
# Importante randomizzare, altrimenti non va bene
X_train, X_test, y_train, y_test = train_test_split(
	X, y, test_size=0.33)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
print('FINITO!')
# Out:
# FINITO!

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array(['non_ironic', 'non_ironic', 'non_ironic', ..., 'non_ironic',
#        'non_ironic', 'non_ironic'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[2355  970]
#  [ 899 8976]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       ironic       0.72      0.71      0.72      3325
#   non_ironic       0.90      0.91      0.91      9875
#
#     accuracy                           0.86     13200
#    macro avg       0.81      0.81      0.81     13200
# weighted avg       0.86      0.86      0.86     13200

# %%
from sklearn.metrics import plot_confusion_matrix

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

disp = plot_confusion_matrix(clf, y_test, y_pred,
							 cmap=plt.cm.Blues)
print(disp.confusion_matrix)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-7fefe74b3af2> in <module>
#       7
#       8 disp = plot_confusion_matrix(clf, y_test, y_pred,
# ----> 9 							 cmap=plt.cm.Blues)
#      10 print(disp.confusion_matrix)
#      11 plt.show()
#
# ~/.local/lib/python3.7/site-packages/sklearn/metrics/_plot/confusion_matrix.py in plot_confusion_matrix(estimator, X, y_true, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax)
#     183         raise ValueError("plot_confusion_matrix only supports classifiers")
#     184
# --> 185     y_pred = estimator.predict(X)
#     186     cm = confusion_matrix(y_true, y_pred, sample_weight=sample_weight,
#     187                           labels=labels, normalize=normalize)
#
# ~/.local/lib/python3.7/site-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
# ...

# %%
import pickle
s = pickle.dumps(clf)
s
# Out:
# b'\x80\x03csklearn.tree._classes\nDecisionTreeClassifier\nq\x00)\x81q\x01}q\x02(X\t\x00\x00\x00criterionq\x03X\x04\x00\x00\x00giniq\x04X\x08\x00\x00\x00splitterq\x05X\x04\x00\x00\x00bestq\x06X\t\x00\x00\x00max_depthq\x07NX\x11\x00\x00\x00min_samples_splitq\x08K\x02X\x10\x00\x00\x00min_samples_leafq\tK\x01X\x18\x00\x00\x00min_weight_fraction_leafq\nG\x00\x00\x00\x00\x00\x00\x00\x00X\x0c\x00\x00\x00max_featuresq\x0bNX\x0c\x00\x00\x00random_stateq\x0cNX\x0e\x00\x00\x00max_leaf_nodesq\rNX\x15\x00\x00\x00min_impurity_decreaseq\x0eG\x00\x00\x00\x00\x00\x00\x00\x00X\x12\x00\x00\x00min_impurity_splitq\x0fNX\x0c\x00\x00\x00class_weightq\x10NX\x07\x00\x00\x00presortq\x11X\n\x00\x00\x00deprecatedq\x12X\t\x00\x00\x00ccp_alphaq\x13G\x00\x00\x00\x00\x00\x00\x00\x00X\x0b\x00\x00\x00n_features_q\x14M\xac\x18X\n\x00\x00\x00n_outputs_q\x15K\x01X\x08\x00\x00\x00classes_q\x16cnumpy.core.multiarray\n_reconstruct\nq\x17cnumpy\nndarray\nq\x18K\x00\x85q\x19C\x01bq\x1a\x87q\x1bRq\x1c(K\x01K\x02\x85q\x1dcnump
# ...

# %%
from joblib import dump, load
dump(clf, 'prova.joblib')
# Out:
# ['aaprova.joblib']

# %%
dataset = '/home/gianlu/Documents/Dev/irony-detection/data/processed/TwReyes2013/labeled_matrix-bow-emot.csv'
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b91aaaf776b6> in <module>
#       1 dataset = '/home/gianlu/Documents/Dev/irony-detection/data/processed/TwReyes2013/labeled_matrix-bow-emot.csv'
# ----> 2 X
#
# NameError: name 'X' is not defined

# %%
X
